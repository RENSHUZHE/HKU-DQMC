# %% [markdown]
# <a href="https://colab.research.google.com/github/RENSHUZHE/HKU-DQMC/blob/main/MonteCarlo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Let's start the Monte Carl Part

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
